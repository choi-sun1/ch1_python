# %%
import random

# %%
#1. 필수 과제 숫자 맞추기게임
answer = random.randint(1,10)
num = int(input("숫자를 입력하세요!"))

while num != answer:
    
    if num > answer:
        print("너무 큽니다. 다시 입력하세요.")
    elif num < answer:
        print("너무 작습니다. 다시 입력하세요.")
    num=int(input("다시 맞춰 보세요!"))
print("정답입니다!")

# %%
import random

answer = random.randint(1,10)
print("1과 10 사이의 숫자를 하나 정했습니다. \n이 숫자는 무엇일까요?")
num = int(input("1~10사이의 숫자를 맞춰보세요!"))

while True:
    if num > answer and num <= 10:
            
        print("너무 큽니다. 다시 입력하세요.")
    elif num < answer and num >= 1:
        
        print("너무 작습니다. 다시 입력하세요.")
    elif num > 10 or num < 1:
        
        print("1~10사이에 숫자를 입력해주세요")
    else:
        print("정답입니다!")
        break
    num=int(input("다시 맞춰 보세요!"))
while True:
    replay = input("게임을 다시 하시겠습니까? (y/n) :").lower()
    if replay == "y":
        break
    elif replay == "n":
        print("게임을 종료합니다. 즐거우셨나요? 또 만나요!")
        exit()
    else:
        print("계속하려면 'y', 그만하려면 'n'을 눌러주세요.")

#while문이 반복되서 함수로 빼서 코딩하는게 좋다.

# %%
#1. 숫자 맞추기 게임 (추가 도전과제)  

import random

def rangame():
    while True:
        try:
            num = int(input("예상 숫자 : "))
            print("예상 숫자 : ",num)
            if num > 10 or num < 1:
                print("1~10사이에 숫자를 입력하세요.")
            elif num == answer:
                print("정답입니다!")
                break
            elif num > answer:
                print("너무 큽니다. 다시 입력하세요.")
            else:
                print("너무 작습니다. 다시 입력하세요.")
        except ValueError:
            print("숫자만 입력해주세요.")
            



while True:
    answer = random.randint(1,10)
    print("1과 10 사이의 숫자를 하나 정했습니다. \n이 숫자는 무엇일까요?")
    rangame()
    
    replay = input("게임을 다시 하시겠습니까? (y/n) :").lower()
    print("게임을 다시 하시겠습니까? (y/n) :",replay)

    while replay not in ["y" , "n"]:
        print("계속하려면 'y' 그만하려면 'n'을 눌러주세요. ")
        replay = input("게임을 다시 하시겠습니까? (y/n) :").lower()
    
    if replay == "n":
        print("게임을 종료합니다. 즐거우셨나요? 또 만나요!")
        break
    elif replay == "y":
        print("게임을 다시 시작합니다.")
# Out:
# 1과 10 사이의 숫자를 하나 정했습니다.
# 이 숫자는 무엇일까요?
# 예상 숫자 :  4
# 너무 큽니다. 다시 입력하세요.
# 예상 숫자 :  2
# 너무 작습니다. 다시 입력하세요.
# 예상 숫자 :  3
# 정답입니다!
# 게임을 다시 하시겠습니까? (y/n) :
# 계속하려면 'y' 그만하려면 'n'을 눌러주세요.
# 게임을 다시 시작합니다.
# 1과 10 사이의 숫자를 하나 정했습니다.
# 이 숫자는 무엇일까요?
# 예상 숫자 :  5
# 너무 작습니다. 다시 입력하세요.
# 숫자만 입력해주세요.
# 예상 숫자 :  5
# 너무 작습니다. 다시 입력하세요.
# 예상 숫자 :  7
# 너무 작습니다. 다시 입력하세요.
# 예상 숫자 :  8
# 너무 작습니다. 다시 입력하세요.
# 예상 숫자 :  9
# 정답입니다!
# 게임을 다시 하시겠습니까? (y/n) :
# 계속하려면 'y' 그만하려면 'n'을 눌러주세요.
# 계속하려면 'y' 그만하려면 'n'을 눌러주세요.
# 게임을 종료합니다. 즐거우셨나요? 또 만나요!

# %%
#2. 이름 성별 나이를 입력받고, 이를 출력하는 프로그램을 작성해주세요.
# 필수과제 클래스와 함수 사용하기.
class Person:
    def __init__(self, name, gender, age):
        self.name = name
        self.gender = gender
        self.age = age
    
    def display(self):
        print(f"이름: {self.name}, 성별: {self.gender} \n나이: {self.age}")

name = input("이름 : ")
gender = input("성별 : ")
age = input("나이 : ")

person = Person(name,gender,age)

person.display()
# Out:
# 이름: 해찬, 성별: 남자
# 나이: 29

# %%
#2. 클래스와 함수 사용하기 + 도전과제

class Person:
    def __init__(self, name, gender, age):
        self.name = name
        self.gender = gender
        self.age = age
    
    def display(self):
        print(f"이름: {self.name} 성별: {self.gender} \n나이: {self.age}")
    
    def greet(self):
        if self.age >19:
            print(f"안녕하세요, {self.name}! 성인이시군요!")
        elif self.age >= 8 and self.age < 19:
            print(f"안녕하세요, {self.name}! 학생이시군요!")
        else:
            print(f"안녕하세요, {self.name}! 반갑습니다!")
            
            
age = int(input("나이 : "))
print("나이 : ", age)
name = input("이름 : ")
print("이름 : ", name)
gender = input("성별 : ")
while True:
    print("성별 : ", gender)
    if gender not in ["male", "female"]:
        print("잘못된 성별을 입력하셨습니다. 'male' 또는 'female'을 입력하세요.")
        gender = input("성별 : ")
    if gender == "male":
        print("성별 : ",gender)
        break
    if gender == "female":
        print("성별 : ",gender)
        break

person = Person(name,gender,age)

person.display()
person.greet()
# Out:
# 나이 :  15
# 이름 :  해찬
# 성별 :  mamamam
# 잘못된 성별을 입력하셨습니다. 'male' 또는 'female'을 입력하세요.
# 성별 :  male
# 이름: 해찬 성별: male
# 나이: 15
# 안녕하세요, 해찬! 학생이시군요!
